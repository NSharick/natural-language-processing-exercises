# %% [markdown]
# ### Data Preparation - NLP

# %%
# unicode, regex, json for text digestion
import unicodedata
import re
import json

# nltk: natural language toolkit -> tokenization, stopwords (more on this soon)
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# pandas dataframe manipulation, acquire script, time formatting
import pandas as pd
import acquire
from time import strftime

# shh, down in front
import warnings
warnings.filterwarnings('ignore')

# %%
blog_1 = acquire.get_blog_posts('https://codeup.com/workshops/from-bootcamp-to-bootcamp-a-military-appreciation-panel/')
blog_2 = acquire.get_blog_posts('https://codeup.com/featured/our-acquisition-of-the-rackspace-cloud-academy-one-year-later/')
blog_3 = acquire.get_blog_posts('https://codeup.com/workshops/virtual/learn-to-code-html-css-on-4-30/')
blog_4 = acquire.get_blog_posts('https://codeup.com/workshops/virtual/learn-to-code-python-workshop-on-4-16/')
blog_5 = acquire.get_blog_posts('https://codeup.com/codeup-news/coming-soon-cloud-administration/')
codeup_df = pd.DataFrame([blog_1, blog_2, blog_3, blog_4, blog_5])
codeup_df
# Out:
#                                                title  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...
# 1  Our Acquisition of the Rackspace Cloud Academy...
# 2                  Learn to Code: HTML & CSS on 4/30
# 3             Learn to Code: Python Workshop on 4/23
# 4                  Coming Soon: Cloud Administration
#
#                                              content
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  According to LinkedIn, the “#1 Most Promising ...
# 4  We’re launching a new program out of San Anton...

# %%
business_articles = acquire.get_news_articles('https://inshorts.com/en/read/business', 'business')
sports_articles = acquire.get_news_articles('https://inshorts.com/en/read/sports', 'sports')
tech_articles = acquire.get_news_articles('https://inshorts.com/en/read/technology', 'technology')
entertainment_articles = acquire.get_news_articles('https://inshorts.com/en/read/entertainment', 'entertainment')
news_df = pd.concat([business_articles, sports_articles, tech_articles, entertainment_articles], axis=0).reset_index(drop=True)
news_df
# Out:
#                                                 title  \
# 0   Rupee closes at all-time low of 77.50 against ...
# 1   India's biggest IPO of LIC subscribed nearly 3...
# 2   Office as we know it, is over: Airbnb CEO on l...
# 3   Microsoft to help cover US employees' travel c...
# 4   Musk's $44 bn Twitter deal at risk of being re...
# ..                                                ...
# 95  We're running shops in mall he built: Ranveer ...
# 96  Helen to make acting comeback after 10 years w...
# 97  Ran out of money during lockdown, in theatre y...
# 98  Didn't attend a wedding in 8yrs of 'Kahaani Gh...
# 99  You have many questions: Debina on trolling fo...
#
#                                               content       category
# 0   The Indian rupee weakened further on Monday to...       business
# 1   LIC's IPO, India's biggest IPO which opened on...       business
# 2   After Airbnb allowed its employees to work rem...       business
# 3   Microsoft has said that it will cover travel c...       business
# 4   Elon Musk's $44 billion offer to buy Twitter c...       business
# ..                                                ...            ...
# 95  Actor Ranveer Singh called Shah Rukh Khan a "p...  entertainment
# 96  Actress Helen will make her comeback to acting...  entertainment
# 97  Actress Sarika said that she ran out of money ...  entertainment
# 98  Actress Sakshi Tanwar has revealed in an inter...  entertainment
# 99  Television actress Debina Bonnerjee has respon...  entertainment
#
# [100 rows x 3 columns]

# %%
def basic_clean(text):
    text = text.lower()
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    text = re.sub(r"[^a-z0-9'\s]", '', text)
    return text

# %%
codeup_df['clean'] = codeup_df.content.apply(basic_clean)

# %%
def tokenize(text):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    text = tokenizer.tokenize(text, return_str=True)
    return text

# %%
tokenized_df = codeup_df.clean.apply(tokenize)

# %%
def stem(text):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in text.split()]
    text = ' '.join(stems)
    return text

# %%
codeup_df['stemmed'] = tokenized_df.apply(stem)

# %%
def lemmatize(text):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in text.split()]
    text = ' '.join(lemmas)
    return text

# %%
codeup_df['lemmatized'] = tokenized_df.apply(lemmatize)

# %%
codeup_df.head()
# Out:
#                                                title  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...
# 1  Our Acquisition of the Rackspace Cloud Academy...
# 2                  Learn to Code: HTML & CSS on 4/30
# 3             Learn to Code: Python Workshop on 4/23
# 4                  Coming Soon: Cloud Administration
#
#                                              content  \
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  According to LinkedIn, the “#1 Most Promising ...
# 4  We’re launching a new program out of San Anton...
#
#                                                clean  \
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html  css are the design building blocks of al...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...
#
#                                              stemmed  \
# 0  in honor of militari appreci month join us for...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html css are the design build block of all the...
# 3  accord to linkedin the 1 most promis job is da...
# 4  were launch a new program out of san antonio w...
#
#                                           lemmatized
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html cs are the design building block of all t...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...

# %% [markdown]
# ---

# %%
news_df['clean'] = news_df.content.apply(basic_clean)
tokenized_df = news_df.clean.apply(tokenize)
news_df['stemmed'] = tokenized_df.apply(stem)
news_df['lemmatized'] = tokenized_df.apply(lemmatize)
news_df.head()
# Out:
#                                                title  \
# 0  Rupee closes at all-time low of 77.50 against ...
# 1  India's biggest IPO of LIC subscribed nearly 3...
# 2  Office as we know it, is over: Airbnb CEO on l...
# 3  Microsoft to help cover US employees' travel c...
# 4  Musk's $44 bn Twitter deal at risk of being re...
#
#                                              content  category  \
# 0  The Indian rupee weakened further on Monday to...  business
# 1  LIC's IPO, India's biggest IPO which opened on...  business
# 2  After Airbnb allowed its employees to work rem...  business
# 3  Microsoft has said that it will cover travel c...  business
# 4  Elon Musk's $44 billion offer to buy Twitter c...  business
#
#                                                clean  \
# 0  the indian rupee weakened further on monday to...
# 1  lic's ipo india's biggest ipo which opened on ...
# 2  after airbnb allowed its employees to work rem...
# 3  microsoft has said that it will cover travel c...
# 4  elon musk's 44 billion offer to buy twitter co...
#
#                                              stemmed  \
# 0  the indian rupe weaken further on monday to cl...
# 1  lic ' s ipo india ' s biggest ipo which open o...
# 2  after airbnb allow it employe to work remot fo...
# 3  microsoft ha said that it will cover travel co...
# 4  elon musk ' s 44 billion offer to buy twitter ...
#
#                                           lemmatized
# 0  the indian rupee weakened further on monday to...
# 1  lic ' s ipo india ' s biggest ipo which opened...
# 2  after airbnb allowed it employee to work remot...
# 3  microsoft ha said that it will cover travel co...
# 4  elon musk ' s 44 billion offer to buy twitter ...

# %% [markdown]
# ---

# %%
def remove_stopwords(text, extra_words= [], exclude_words= []):
    stopword_list = stopwords.words('english')
    stopword_list = set(stopword_list) - set(exclude_words)
    stopword_list = stopword_list.union(set(extra_words))
    words = text.split()
    filtered_words = [w for w in words if w not in stopword_list]
    text_without_stopwords = ' '.join(filtered_words)
    return text_without_stopwords

# %%
codeup_df['stemmed_stopwords_removed'] = codeup_df.stemmed.apply(remove_stopwords)

# %%
codeup_df
# Out:
#                                                title  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...
# 1  Our Acquisition of the Rackspace Cloud Academy...
# 2                  Learn to Code: HTML & CSS on 4/30
# 3             Learn to Code: Python Workshop on 4/23
# 4                  Coming Soon: Cloud Administration
#
#                                              content  \
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  According to LinkedIn, the “#1 Most Promising ...
# 4  We’re launching a new program out of San Anton...
#
#                                                clean  \
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html  css are the design building blocks of al...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...
#
#                                              stemmed  \
# 0  in honor of militari appreci month join us for...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html css are the design build block of all the...
# 3  accord to linkedin the 1 most promis job is da...
# 4  were launch a new program out of san antonio w...
#
#                                           lemmatized  \
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html cs are the design building block of all t...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...
#
#                            stemmed_stopwords_removed
# 0  honor militari appreci month join us discuss c...
# 1  year ago april 16th 2021 announc acquisit rack...
# 2  html css design build block websit interact da...
# 3  accord linkedin 1 promis job data scienc codeu...
# 4  launch new program san antonio acquisit racksp...

# %%
codeup_df['lem_stopwords_removed'] = codeup_df.lemmatized.apply(remove_stopwords)

# %%
codeup_df
# Out:
#                                                title  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...
# 1  Our Acquisition of the Rackspace Cloud Academy...
# 2                  Learn to Code: HTML & CSS on 4/30
# 3             Learn to Code: Python Workshop on 4/23
# 4                  Coming Soon: Cloud Administration
#
#                                              content  \
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# 3  According to LinkedIn, the “#1 Most Promising ...
# 4  We’re launching a new program out of San Anton...
#
#                                                clean  \
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html  css are the design building blocks of al...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...
#
#                                              stemmed  \
# 0  in honor of militari appreci month join us for...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html css are the design build block of all the...
# 3  accord to linkedin the 1 most promis job is da...
# 4  were launch a new program out of san antonio w...
#
#                                           lemmatized  \
# 0  in honor of military appreciation month join u...
# 1  just about a year ago on april 16th 2021 we an...
# 2  html cs are the design building block of all t...
# 3  according to linkedin the 1 most promising job...
# 4  were launching a new program out of san antoni...
#
#                            stemmed_stopwords_removed  \
# 0  honor militari appreci month join us discuss c...
# 1  year ago april 16th 2021 announc acquisit rack...
# 2  html css design build block websit interact da...
# 3  accord linkedin 1 promis job data scienc codeu...
# 4  launch new program san antonio acquisit racksp...
#
#                                lem_stopwords_removed
# 0  honor military appreciation month join u discu...
# 1  year ago april 16th 2021 announced acquisition...
# 2  html cs design building block website interact...
# 3  according linkedin 1 promising job data scienc...
# 4  launching new program san antonio acquisition ...
